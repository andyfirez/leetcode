# %%
from typing import List

# %% [markdown]
# Мое решение:
# Используем frozenset в качестве ключей для словаря

# %%
def get_counts(string: str) -> dict:
    res = {}
    # for c in string:
    #     if c not in res:
    #         res[c] = 0
    #     res[c] += 1

    for c in string:
        res[c] = res.get(c, 0) + 1

    return res

def groupAnagrams(strs: List[str]) -> List[List[str]]:
    anagrams = {}

    for str in strs:
        count_dict = get_counts(str)
        str_set = frozenset(count_dict.items())
        # if str_set not in anagrams:
        #     anagrams[str_set] = []

        # anagrams[str_set].append(str)

        anagrams.setdefault(str_set, []).append(str)

    return list(anagrams.values())

# %% [markdown]
# Идеоматическое решение
# - Используем кортежи счетчиков вместо словаря
# - индексом в кортеже выступает относительный индекс символа в таблице asci

# %%
from collections import defaultdict
def groupAnagrams(strs: List[str]) -> List[List[str]]:
    anagrams = defaultdict(list)
    for s in strs:
        count = [0] * 26
        for c in s:
            count[ord(c) - ord('a')] += 1
        anagrams[tuple(count)].append(s)
    return list(anagrams.values())

# %%
strs = ["eat","tea","tan","ate","nat","bat"]
print(groupAnagrams(strs))
# Out:
# [['eat', 'tea', 'ate'], ['tan', 'nat'], ['bat']]

# %%
strs = [""]
print(groupAnagrams(strs))
# Out:
# [['']]

# %%
strs = ["a"]
print(groupAnagrams(strs))
# Out:
# [['a']]

# %%
strs = ["ddddddddddg","dgggggggggg"]
print(groupAnagrams(strs))
# Out:
# [['ddddddddddg'], ['dgggggggggg']]
